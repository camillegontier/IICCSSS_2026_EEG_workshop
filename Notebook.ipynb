# %% [markdown]
# Visualize the raw EEG signal

# %% [markdown]
# Visualize the filtered EEG signal

# %% [markdown]
# Visualize the raw EEG signal

# %% [markdown]
# Visualize the raw EEG signal

# %% [markdown]
# Sanity check: the Berger effect

# %% [markdown]
# Sanity check: brainwave entrainment
